# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from src.quant.risk_metrics import compute_metrics

metrics = compute_metrics()
metrics
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.quant.risk_metrics import compute_metrics
#       3 metrics = compute_metrics()
#       4 metrics
#
# ModuleNotFoundError: No module named 'src'

# %%
plt.bar(metrics["ticker"], metrics["sharpe"])
plt.title("Sharpe Ratio")
plt.show()

# %%
plt.bar(metrics["ticker"], metrics["max_drawdown"])
plt.title("Max Drawdown")
plt.show()
