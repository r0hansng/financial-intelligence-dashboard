# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_parquet("../data/processed/AAPL.parquet")
df.head()
# Out:
#         date      Close       High        Low       Open     Volume      price
# 0 2015-01-02  24.214899  24.682231  23.776359  24.671157  212818400  24.214899
# 1 2015-01-05  23.532719  24.064282  23.346673  23.984547  257142000  23.532719
# 2 2015-01-06  23.534935  23.794071  23.173914  23.596950  263188400  23.534935
# 3 2015-01-07  23.864948  23.964616  23.632389  23.743131  160423600  23.864948
# 4 2015-01-08  24.781895  24.839481  24.075359  24.192747  237458000  24.781895

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2838 entries, 0 to 2837
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    2838 non-null   datetime64[ns]
#  1   Close   2838 non-null   float64
#  2   High    2838 non-null   float64
#  3   Low     2838 non-null   float64
#  4   Open    2838 non-null   float64
#  5   Volume  2838 non-null   int64
#  6   price   2838 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 155.3 KB
#                                 date        Close         High          Low  \
# count                           2838  2838.000000  2838.000000  2838.000000
# mean   2020-08-21 21:37:55.687103744   110.126828   111.225377   108.928093
# min              2015-01-02 00:00:00    20.584816    20.887866    20.386579
# 25%              2017-10-25 06:00:00    37.122095    37.444130    36.753758
# 50%              2020-08-20 12:00:00   108.256561   109.773543   106.193405
# 75%              2023-06-15 18:00:00   171.182426   172.207032   169.257129
# max              2026-04-16 00:00:00   285.922455   288.350192   283.035157
# std                              NaN    77.200912    77.952530    76.382766
#
#               Open        Volume        price
# count  2838.000000  2.838000e+03  2838.000000
# mean    110.037029  1.097606e+08   110.126828
# min      20.507342  1.791060e+07    20.584816
# 25%      37.114352  6.262860e+07    37.122095
# 50%     108.538112  9.289040e+07   108.256561
# 75%     170.915935  1.354843e+08   171.182426
# max     285.932471  6.488252e+08   285.922455
# std      77.140196  6.798008e+07    77.200912

# %%
df.isna().sum()
# Out:
# date      0
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# price     0
# dtype: int64

# %%
print(df["date"].min(), df["date"].max())
# Out:
# 2015-01-02 00:00:00 2026-04-16 00:00:00

# %%
plt.figure()
plt.plot(df["date"], df["price"])
plt.title("AAPL Price Trend")
plt.show()

# %%
plt.figure()
plt.hist(df["price"], bins=50)
plt.title("Price Distribution")
plt.show()
